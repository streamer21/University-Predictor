# %% [markdown]
# #### Importing all the necessary libraries!!!!!!!!!!!!!!!!!! ###

# %%
import pandas as pd                                #for data manipulation
import numpy as np                                 #for mathematical functions 
import matplotlib.pyplot as plt                    #for data plotting
import seaborn as sns                              #for data visualization
# %matplotlib inline

# %% [markdown]
# #### Now we have downloaded the dataset as a .csv file in our computer.We are going to read that here in this notebook ###

# %%
data=pd.read_csv('Admission_Predict.csv')
data.head(7)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
# 5           6        330          115                  5  4.5   3.0  9.34
# 6           7        321          109                  3  3.0   4.0  8.20
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65
# 5         1              0.90
# 6         1              0.75

# %% [markdown]
# #### Renaming the column names.

# %%
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
data.columns=['No','GRE','TOEFL','Ranking','SOP','LOR','CGPA','Research','Chance']
data.columns
# Out:
# Index(['No', 'GRE', 'TOEFL', 'Ranking', 'SOP', 'LOR', 'CGPA', 'Research',
#        'Chance'],
#       dtype='object')

# %%
data.head(7)
# Out:
#    No  GRE  TOEFL  Ranking  SOP  LOR  CGPA  Research  Chance
# 0   1  337    118        4  4.5  4.5  9.65         1    0.92
# 1   2  324    107        4  4.0  4.5  8.87         1    0.76
# 2   3  316    104        3  3.0  3.5  8.00         1    0.72
# 3   4  322    110        3  3.5  2.5  8.67         1    0.80
# 4   5  314    103        2  2.0  3.0  8.21         0    0.65
# 5   6  330    115        5  4.5  3.0  9.34         1    0.90
# 6   7  321    109        3  3.0  4.0  8.20         1    0.75

# %% [markdown]
# #### Analyzing different components of the dataset.

# %%
len(data)         #It will allow us to know how many data samples are available to us
# Out:
# 400

# %%
data.shape        #.shape gives us the number of rows and models that our dataset contains
# Out:
# (400, 9)

# %% [markdown]
# #### Statistical analysis of the dataset

# %%
data.dtypes       # Understanding the the data types of different columns of our dataset
# Out:
# No            int64
# GRE           int64
# TOEFL         int64
# Ranking       int64
# SOP         float64
# LOR         float64
# CGPA        float64
# Research      int64
# Chance      float64
# dtype: object

# %%
data.info()     
"""Data types of the features and null values present in each columns.
This is the overview of each columns"""
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        400 non-null    int64
#  1   GRE       400 non-null    int64
#  2   TOEFL     400 non-null    int64
#  3   Ranking   400 non-null    int64
#  4   SOP       400 non-null    float64
#  5   LOR       400 non-null    float64
#  6   CGPA      400 non-null    float64
#  7   Research  400 non-null    int64
#  8   Chance    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB
# 'Data types of the features and null values present in each columns.\nThis is the overview of each columns'

# %%
""" 
Another way to check if there are any null values present in the columns.
If null values are there , it will be a barrier when we do exploratory data analysis
and while running machine learning models later.So checking this is very necessary and important
"""

data.isnull().sum()
# Out:
# No          0
# GRE         0
# TOEFL       0
# Ranking     0
# SOP         0
# LOR         0
# CGPA        0
# Research    0
# Chance      0
# dtype: int64

# %%
"""
.describe() gives us all the statistical components of each columns like mean,maximum etc...
This is a very important part of data analysis

"""
data.describe()
# Out:
#                No         GRE       TOEFL     Ranking         SOP         LOR  \
# count  400.000000  400.000000  400.000000  400.000000  400.000000  400.000000
# mean   200.500000  316.807500  107.410000    3.087500    3.400000    3.452500
# std    115.614301   11.473646    6.069514    1.143728    1.006869    0.898478
# min      1.000000  290.000000   92.000000    1.000000    1.000000    1.000000
# 25%    100.750000  308.000000  103.000000    2.000000    2.500000    3.000000
# 50%    200.500000  317.000000  107.000000    3.000000    3.500000    3.500000
# 75%    300.250000  325.000000  112.000000    4.000000    4.000000    4.000000
# max    400.000000  340.000000  120.000000    5.000000    5.000000    5.000000
#
#              CGPA    Research      Chance
# count  400.000000  400.000000  400.000000
# mean     8.598925    0.547500    0.724350
# std      0.596317    0.498362    0.142609
# min      6.800000    0.000000    0.340000
# 25%      8.170000    0.000000    0.640000
# ...

# %% [markdown]
# #### Now we will do some statistical analysis on our own using numpy and pandas library

# %%
"""
.value_counts(): This is very efficient function of pandas used for getting the frequency of each 
attribute in a particular columns


For example 
If we need to know how many students have applied for college ranking 1,2,3,4 and 5 individually
THIS IS ONLY FOR COLUMNS WHICH HAS DISCRETE VALUES.
.value_counts() is able to do that
"""
data['Ranking'].value_counts()
# Out:
# 3    133
# 2    107
# 4     74
# 5     60
# 1     26
# Name: Ranking, dtype: int64

# %%
data['SOP'].value_counts()
# Out:
# 3.5    70
# 4.0    70
# 3.0    64
# 4.5    53
# 2.5    47
# 5.0    37
# 2.0    33
# 1.5    20
# 1.0     6
# Name: SOP, dtype: int64

# %%
data['LOR'].value_counts()
# Out:
# 3.0    85
# 4.0    77
# 3.5    73
# 4.5    45
# 2.5    39
# 2.0    38
# 5.0    35
# 1.5     7
# 1.0     1
# Name: LOR, dtype: int64

# %%
data['Research'].value_counts()
# Out:
# 1    219
# 0    181
# Name: Research, dtype: int64

# %%
"""
.groupby(): It allow to understand the features of other columns with respect to
one particular column which has discrete values.
"""
data.groupby('Ranking').mean()
# Out:
#                  No         GRE       TOEFL       SOP       LOR      CGPA  \
# Ranking
# 1        233.807692  303.153846   99.076923  1.884615  2.211538  7.745769
# 2        214.813084  309.177570  103.523364  2.705607  2.925234  8.183738
# 3        204.165414  315.954887  106.887218  3.364662  3.402256  8.552256
# 4        199.594595  324.824324  111.824324  4.108108  4.006757  9.021622
# 5        153.533333  328.333333  113.666667  4.500000  4.358333  9.291167
#
#          Research    Chance
# Ranking
# 1        0.192308  0.548077
# 2        0.299065  0.625981
# 3        0.533835  0.711880
# 4        0.797297  0.818108
# 5        0.866667  0.888167

# %%
data.groupby('SOP').mean()
# Out:
#              No         GRE       TOEFL   Ranking       LOR      CGPA  \
# SOP
# 1.0  273.166667  304.000000   99.000000  1.166667  1.916667  7.765000
# 1.5  211.450000  302.250000   99.000000  1.800000  2.225000  7.726500
# 2.0  221.121212  308.606061  102.666667  2.151515  2.651515  8.061818
# 2.5  254.936170  310.042553  103.468085  2.191489  2.872340  8.248298
# 3.0  188.062500  313.906250  105.765625  2.687500  3.148438  8.390156
# 3.5  214.042857  315.900000  107.485714  2.957143  3.421429  8.580714
# 4.0  163.771429  321.400000  110.028571  3.571429  3.907143  8.854571
# 4.5  183.377358  326.377358  112.622642  4.132075  4.103774  9.133019
# 5.0  185.162162  327.000000  112.837838  4.594595  4.608108  9.277027
#
#      Research    Chance
# SOP
# 1.0  0.166667  0.538333
# 1.5  0.150000  0.521500
# 2.0  0.181818  0.602727
# 2.5  0.297872  0.651277
# 3.0  0.468750  0.683594
# 3.5  0.614286  0.713571
# 4.0  0.700000  0.778000
# 4.5  0.773585  0.843962
# 5.0  0.864865  0.883514

# %%
data.groupby('LOR').mean()
# Out:
#              No         GRE       TOEFL   Ranking       SOP      CGPA  \
# LOR
# 1.0  348.000000  299.000000   94.000000  1.000000  1.000000  7.340000
# 1.5  221.285714  307.714286  102.142857  1.571429  2.071429  8.038571
# 2.0  213.342105  304.921053  101.131579  1.894737  2.171053  7.866842
# 2.5  225.538462  310.897436  104.153846  2.461538  2.474359  8.202821
# 3.0  186.094118  313.835294  105.964706  2.647059  3.094118  8.420941
# 3.5  213.000000  316.465753  107.273973  3.013699  3.438356  8.594521
# 4.0  204.909091  320.311688  108.961039  3.493506  3.870130  8.798831
# 4.5  173.511111  325.911111  112.822222  4.133333  4.322222  9.172889
# 5.0  184.200000  327.142857  112.714286  4.428571  4.542857  9.246857
#
#      Research    Chance
# LOR
# 1.0  0.000000  0.420000
# 1.5  0.285714  0.567143
# 2.0  0.236842  0.563158
# 2.5  0.256410  0.632564
# 3.0  0.470588  0.674235
# 3.5  0.520548  0.721096
# 4.0  0.688312  0.776364
# 4.5  0.844444  0.858444
# 5.0  0.828571  0.883429

# %%
data.groupby('Research').mean()
# Out:
#                   No         GRE       TOEFL   Ranking       SOP       LOR  \
# Research
# 0         208.519337  309.491713  104.143646  2.524862  2.908840  3.060773
# 1         193.872146  322.853881  110.109589  3.552511  3.805936  3.776256
#
#               CGPA    Chance
# Research
# 0         8.257182  0.637680
# 1         8.881370  0.795982

# %%
"""
We can all come up with our own method and types of data analysis.Everyone can 
come up with different conclusions and inference

First let us analyse what are the performance score of student who are applying for top most colleges
Thats us colleges whose college ranking is 5 Star
"""
data[data['Ranking']==5].describe()
# Out:
#                No         GRE       TOEFL  Ranking        SOP        LOR  \
# count   60.000000   60.000000   60.000000     60.0  60.000000  60.000000
# mean   153.533333  328.333333  113.666667      5.0   4.500000   4.358333
# std     97.709959    8.524475    4.261243      0.0   0.520756   0.582889
# min      6.000000  303.000000  103.000000      5.0   3.000000   3.000000
# 25%     72.750000  323.000000  111.000000      5.0   4.000000   4.000000
# 50%    134.500000  330.000000  114.000000      5.0   4.500000   4.500000
# 75%    206.500000  334.000000  117.000000      5.0   5.000000   5.000000
# max    386.000000  340.000000  120.000000      5.0   5.000000   5.000000
#
#             CGPA   Research     Chance
# count  60.000000  60.000000  60.000000
# mean    9.291167   0.866667   0.888167
# std     0.352103   0.342803   0.076035
# min     8.480000   0.000000   0.610000
# 25%     9.080000   1.000000   0.870000
# 50%     9.325000   1.000000   0.910000
# ...

# %% [markdown]
# #### A very common question asked is how should a students performance be if that person wantsto get into a top college?This can be answered....

# %%
"""

Now lets us analyze the attributes of students who are applying for top colleges 
and whose chances of admission are very high
"""
data[(data['Ranking']==5) & (data['Chance']>0.9)].head()
# Out:
#     No  GRE  TOEFL  Ranking  SOP  LOR  CGPA  Research  Chance
# 22  23  328    116        5  5.0  5.0   9.5         1    0.94
# 23  24  334    119        5  5.0  4.5   9.7         1    0.95
# 24  25  336    119        5  4.0  3.5   9.8         1    0.97
# 25  26  340    120        5  4.5  4.5   9.6         1    0.94
# 34  35  331    112        5  4.0  5.0   9.8         1    0.94

# %%
data[(data['Ranking']==5) & (data['Chance']>0.9)].describe()
# Out:
#                No         GRE      TOEFL  Ranking       SOP        LOR  \
# count   32.000000   32.000000   32.00000     32.0  32.00000  32.000000
# mean   151.781250  332.562500  116.18750      5.0   4.62500   4.531250
# std    102.008138    5.085955    2.71718      0.0   0.40161   0.522671
# min     23.000000  320.000000  110.00000      5.0   4.00000   3.500000
# 25%     72.750000  331.000000  115.00000      5.0   4.50000   4.375000
# 50%    130.500000  333.000000  116.00000      5.0   4.50000   4.500000
# 75%    206.500000  336.000000  118.00000      5.0   5.00000   5.000000
# max    386.000000  340.000000  120.00000      5.0   5.00000   5.000000
#
#             CGPA  Research     Chance
# count  32.000000      32.0  32.000000
# mean    9.514375       1.0   0.937813
# std     0.210773       0.0   0.017549
# min     9.190000       1.0   0.910000
# 25%     9.360000       1.0   0.927500
# 50%     9.460000       1.0   0.940000
# 75%     9.715000       1.0   0.942500
# ...

# %%
"""
Now this is very very important in machine learning.If there are any two columns who are inter-related 
to one another.This can be found using the correlation function of pandas 
Every value is between (-1) to (1)

The higher the value ,the higher is ther correaltion
and the lesse the value, the lower is their correlation
"""
data.corr()
# Out:
#                 No       GRE     TOEFL   Ranking       SOP       LOR  \
# No        1.000000 -0.097526 -0.147932 -0.169948 -0.166932 -0.088221
# GRE      -0.097526  1.000000  0.835977  0.668976  0.612831  0.557555
# TOEFL    -0.147932  0.835977  1.000000  0.695590  0.657981  0.567721
# Ranking  -0.169948  0.668976  0.695590  1.000000  0.734523  0.660123
# SOP      -0.166932  0.612831  0.657981  0.734523  1.000000  0.729593
# LOR      -0.088221  0.557555  0.567721  0.660123  0.729593  1.000000
# CGPA     -0.045608  0.833060  0.828417  0.746479  0.718144  0.670211
# Research -0.063138  0.580391  0.489858  0.447783  0.444029  0.396859
# Chance    0.042336  0.802610  0.791594  0.711250  0.675732  0.669889
#
#               CGPA  Research    Chance
# No       -0.045608 -0.063138  0.042336
# GRE       0.833060  0.580391  0.802610
# TOEFL     0.828417  0.489858  0.791594
# Ranking   0.746479  0.447783  0.711250
# SOP       0.718144  0.444029  0.675732
# ...
